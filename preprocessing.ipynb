# %%
import pandas as pd
import re
from langdetect import detect

# %%
df = pd.read_csv('reviews.csv', sep=';', encoding='utf-8', index_col='Unnamed: 0')
df
# Out:
#                                                    review  \
# 0       \n\n\n\n\n\n                Cringe "comedy" in...
# 1       \n\n\n\n\n\n                So this is the thi...
# 2       \n\n\n\n\n\n                The show is depres...
# 3       \n\n\n\n\n\n                Ugly CGI, bland vi...
# 4       \n\n\n\n\n\n                Boring. Cliche. La...
# ...                                                   ...
# 242138  \n\n\n\n\n\n                A comedy/romance b...
# 242139  \n\n\n\n\n\n                Saiyuki is one of ...
# 242140  \n\n\n\n\n\n                First, let me say ...
# 242141  \n\n\n\n\n\n                Utawarerumono mana...
# 242142  \n\n\n\n\n\n                Cowboy Bebop is an...
#
#                                                     title  \
# 0                                    Amagi Brilliant Park
# 1       Higeki no Genkyou to Naru Saikyou Gedou Last B...
# 2                                       Sousou no Frieren
# 3                                        Kimetsu no Yaiba
# 4                                          Ousama Ranking
# ...                                                   ...
# 242138                                            Ranma ½
# 242139                               Gensoumaden Saiyuuki
# 242140                                     Hajime no Ippo
# 242141                                      Utawarerumono
# 242142                                       Cowboy Bebop
#
#                                                       tag  rating
# 0       Not RecommendedPreliminary\n                \n...       2
# 1                                          Mixed Feelings       5
# 2       RecommendedPreliminary\n                \n    ...       9
# 3                                         Not Recommended       3
# 4                                         Not Recommended       2
# ...                                                   ...     ...
# 242138                                        Recommended       7
# 242139                                        Recommended       9
# 242140                                        Recommended      10
# 242141                                        Recommended       8
# 242142                                        Recommended      10
#
# [242143 rows x 4 columns]

# %% [markdown]
# Removing extra data and symbols from the "tag" column as some rows have not been parsed correctly.

# %%
new_tag_list = []
for tag in list(df.tag):
    if tag.startswith('Recommended'):
        new_tag = 'Recommended'
    elif tag.startswith('Mixed Feelings'):
        new_tag = 'Mixed Feelings'
    elif tag.startswith('Not Recommended'):
        new_tag = 'Not Recommended'
    new_tag_list.append(new_tag)

df.tag = new_tag_list
df
# Out:
#                                                    review  \
# 0       \n\n\n\n\n\n                Cringe "comedy" in...
# 1       \n\n\n\n\n\n                So this is the thi...
# 2       \n\n\n\n\n\n                The show is depres...
# 3       \n\n\n\n\n\n                Ugly CGI, bland vi...
# 4       \n\n\n\n\n\n                Boring. Cliche. La...
# ...                                                   ...
# 242138  \n\n\n\n\n\n                A comedy/romance b...
# 242139  \n\n\n\n\n\n                Saiyuki is one of ...
# 242140  \n\n\n\n\n\n                First, let me say ...
# 242141  \n\n\n\n\n\n                Utawarerumono mana...
# 242142  \n\n\n\n\n\n                Cowboy Bebop is an...
#
#                                                     title              tag  \
# 0                                    Amagi Brilliant Park  Not Recommended
# 1       Higeki no Genkyou to Naru Saikyou Gedou Last B...   Mixed Feelings
# 2                                       Sousou no Frieren      Recommended
# 3                                        Kimetsu no Yaiba  Not Recommended
# 4                                          Ousama Ranking  Not Recommended
# ...                                                   ...              ...
# 242138                                            Ranma ½      Recommended
# 242139                               Gensoumaden Saiyuuki      Recommended
# 242140                                     Hajime no Ippo      Recommended
# 242141                                      Utawarerumono      Recommended
# 242142                                       Cowboy Bebop      Recommended
#
#         rating
# 0            2
# 1            5
# 2            9
# 3            3
# 4            2
# ...        ...
# 242138       7
# 242139       9
# 242140      10
# 242141       8
# 242142      10
#
# [242143 rows x 4 columns]

# %% [markdown]
# Cleaning the reviews from extra symbols and numbers.

# %%
def preprocess(text):
    text = re.sub(r'[\n\r\s]+', ' ', text)
    # text = re.sub(r'[\.,\!\?\"\-:;\\\/\=\(\)•★%\*\[\]\$#@…_]+', ' ', text)
    text = re.sub(r'[=•★%\*\[\]\$#@…_\"\\\/“”]', ' ', text)
    text = re.sub(r'([.])\1+', r'\1', text)
    text = re.sub(r'\’', '\'', text)
    text = re.sub(r'[0-9]+', ' ', text)
    text = re.sub(r'\s\s+', ' ', text)
    return text.strip()

# %%
df['cleaned_review'] = df['review'].apply(preprocess)
df
# Out:
#                                                    review  \
# 0       \n\n\n\n\n\n                Cringe "comedy" in...
# 1       \n\n\n\n\n\n                So this is the thi...
# 2       \n\n\n\n\n\n                The show is depres...
# 3       \n\n\n\n\n\n                Ugly CGI, bland vi...
# 4       \n\n\n\n\n\n                Boring. Cliche. La...
# ...                                                   ...
# 242138  \n\n\n\n\n\n                A comedy/romance b...
# 242139  \n\n\n\n\n\n                Saiyuki is one of ...
# 242140  \n\n\n\n\n\n                First, let me say ...
# 242141  \n\n\n\n\n\n                Utawarerumono mana...
# 242142  \n\n\n\n\n\n                Cowboy Bebop is an...
#
#                                                     title              tag  \
# 0                                    Amagi Brilliant Park  Not Recommended
# 1       Higeki no Genkyou to Naru Saikyou Gedou Last B...   Mixed Feelings
# 2                                       Sousou no Frieren      Recommended
# 3                                        Kimetsu no Yaiba  Not Recommended
# 4                                          Ousama Ranking  Not Recommended
# ...                                                   ...              ...
# 242138                                            Ranma ½      Recommended
# 242139                               Gensoumaden Saiyuuki      Recommended
# 242140                                     Hajime no Ippo      Recommended
# 242141                                      Utawarerumono      Recommended
# 242142                                       Cowboy Bebop      Recommended
#
#         rating                                     cleaned_review
# 0            2  Cringe comedy in a nutshell except there's not...
# 1            5  So this is the thing about this anime. some sp...
# 2            9  The show is depressing as fuck. But good. As f...
# 3            3  Ugly CGI, bland villains, bland one-dimensiona...
# 4            2  Boring. Cliche. Lame. Ousama Ranking is extrem...
# ...        ...                                                ...
# 242138       7  A comedy romance based on the manga by Rumiko ...
# 242139       9  Saiyuki is one of those animes that just grabs...
# 242140      10  First, let me say that I 'm not a fan of boxin...
# 242141       8  Utawarerumono manages to be one of those harem...
# 242142      10  Cowboy Bebop is an episodic series. By episodi...
#
# [242143 rows x 5 columns]

# %%
df.to_csv('reviews_clean_with_non_en.csv', sep=';', encoding='utf-8') 
# saving a provisional dataframe before removing non-EN reviews as detecting them takes a while

# %% [markdown]
# Cleaning the dataset from non-English reviews using the langdetect library.

# %%
indices_non_en = []

for index, row in df.iterrows():
    try:
        detected_language = detect(row.cleaned_review)
        if detected_language != 'en':
            indices_non_en.append(index)
    except:
        continue

df.drop(indices_non_en, inplace=True)

# %%
df.to_csv('reviews_clean.csv', sep=';', encoding='utf-8')
